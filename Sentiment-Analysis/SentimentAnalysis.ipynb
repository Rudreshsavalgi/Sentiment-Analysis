# %% [markdown]
# ### Data Collection

# %%
#extracting data from zip file
import zipfile
PATH = '/content/drive/My Drive/Datasets/database.sqlite.zip'
with zipfile.ZipFile(PATH,'r') as zip_ref:
    zip_ref.extractall('')

# %%
import sqlite3
import pandas as pd
cnx = sqlite3.connect('/content/database.sqlite')
#importing the data
df = pd.read_sql_query("SELECT * FROM sentiment",cnx)

# %%
df.head()
# Out:
#    id               candidate  ...  tweet_location               user_timezone
# 0   1  No candidate mentioned  ...                                       Quito
# 1   2            Scott Walker  ...
# 2   3  No candidate mentioned  ...
# 3   4  No candidate mentioned  ...           Texas  Central Time (US & Canada)
# 4   5            Donald Trump  ...                                     Arizona
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Importing Essential Libraries

# %%
# This Python 3 environtment comes with many helpful
import numpy as np
# CountVectorizer is used to convert the text to vector form
from sklearn.feature_extraction.text import CountVectorizer
# Tokenizer converts sentences to list of unique word
from tensorflow.keras.preprocessing.text import Tokenizer
# pad_sequences for padding the sentences to match the smaller sizes of max sentence size
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Sequential model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,LSTM,SpatialDropout1D
from sklearn.model_selection import train_test_split
import re
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Performing EDA and Data Preprocessing

# %%
#only selecting 'text' and 'sentiment' columns
data = df[['text','sentiment']]

# %%
#number of unique categories 
set(data['sentiment'])
# Out:
# {'Negative', 'Neutral', 'Positive'}

# %%
#values in each categories
data['sentiment'].value_counts()
# Out:
# Negative    8493
# Neutral     3142
# Positive    2236
# Name: sentiment, dtype: int64

# %%
# filtering out the neutral ones
data = data[data.sentiment != 'Neutral']

# %%
data['sentiment'].value_counts()
# Out:
# Negative    8493
# Positive    2236
# Name: sentiment, dtype: int64

# %% [markdown]
# #### Data Cleaning:
# Following steps are performed in cleaning the data
# 1. converting to lower case
# 2. remove non alpha-numerical values
# 3. removing 'rt' which is common in all the tweets

# %%
data['text'] = data['text'].apply(lambda x:x.lower()) #converts to lower case
data['text'] = data['text'].apply(lambda x:re.sub('[^a-zA-Z0-9\s]','',x)) #only alpha numerical and white spaces are allowed

# %%
data['text'].head()
# Out:
# 1    rt scottwalker didnt catch the full gopdebate ...
# 3    rt robgeorge that carly fiorina is trending  h...
# 4    rt danscavino gopdebate w realdonaldtrump deli...
# 5    rt gregabbotttx tedcruz on my first day i will...
# 6    rt warriorwoman91 i liked her and was happy wh...
# Name: text, dtype: object

# %%
# replacing rt with '' 
for idx,row in data.iterrows():
  row[0] = row[0].replace('rt','')

# %%
data['text'].head()
# Out:
# 1     scottwalker didnt catch the full gopdebate la...
# 3     robgeorge that carly fiorina is trending  hou...
# 4     danscavino gopdebate w realdonaldtrump delive...
# 5     gregabbotttx tedcruz on my first day i will r...
# 6     warriorwoman91 i liked her and was happy when...
# Name: text, dtype: object

# %% [markdown]
# #### Tokenizer

# %%
max_features = 2000
#max 2000 words(most common words) and splits on space
tokenizer = Tokenizer(num_words = max_features,split = ' ')
tokenizer.fit_on_texts(data['text'].values)
X = tokenizer.texts_to_sequences(data['text'].values)
923, 90, 734, 36, 1307], [15, 5, 7, 625, 1, 8, 79, 735, 27, 1, 951, 2], [1746, 12, 1, 292, 1042, 2], [368, 319, 2], [15, 313, 6, 72, 1747, 1748, 5, 7, 268, 642, 360, 81, 7, 715, 360, 2], [54, 1, 2, 1749, 329], [1242, 2, 307, 23, 1920, 1, 1606, 213, 12, 1, 691, 6, 183, 204, 366, 18, 142, 181], [660, 331, 2, 595, 336, 345, 6, 189, 4, 257, 279, 811, 995], [44, 235, 1089, 105, 238, 576, 367, 8, 23, 4, 107, 104], [643, 7, 104, 83, 12, 1, 346, 36, 107, 24, 111, 1090, 190, 12, 20, 26, 377, 13, 81, 19, 1136, 2], [1188, 391, 406, 8, 44, 5, 1243, 1308, 23, 661, 531, 909, 521, 2], [1388, 9, 261, 1091, 51, 40, 105, 484, 27, 112, 70, 126, 39, 58, 32, 596, 383, 5, 2], [4, 2, 88, 91, 54, 405, 118, 80, 1309, 22, 1504], [1391, 1, 2, 812, 4, 329, 21, 1137], [283, 106, 33, 662, 996, 62, 32, 16, 1609, 12, 996, 62, 1924, 997, 2, 630], [1925, 316, 42, 56, 11, 84, 4, 377, 881, 2], [1092, 543, 8, 92, 1093, 1926, 125, 97, 79, 6, 1, 154, 2, 882, 693, 910], [2, 415, 736], [880, 813, 468, 9, 1750, 47, 45, 51, 39, 58, 1927, 44, 436, 24, 74, 98, 2, 467], [437, 447, 1, 2, 1928, 544, 106, 40, 184, 998, 6, 15, 102, 103, 522, 545, 73, 262], [37, 270, 53, 260, 4, 178, 41, 814, 62, 169, 2, 473, 249], [56, 30, 84, 4, 377, 1043, 4, 16, 111, 64, 30, 485, 45, 2], [78, 277, 493, 1929, 304, 546, 269, 361, 36, 208, 49, 8, 40, 200, 16, 94], [1391, 323, 336, 43, 1392, 15, 82, 151, 34, 911, 89, 4, 644, 30, 911, 1310, 57, 1311, 2, 262], [18, 25, 184, 81, 457, 2, 1505, 281, 151, 486, 1189, 27, 1751, 249, 24, 354, 15, 69, 6, 414], [242, 66, 67, 269, 85, 118, 128, 460, 22, 1312, 1393, 398, 14, 781, 761, 39, 58, 12, 1, 2, 9], [316, 283, 2], [1094, 999, 2, 783, 8, 105, 1, 7, 1190, 12, 1, 260, 26, 952, 26, 21, 99], [1, 186, 4, 346, 8, 139, 201, 17, 51, 5, 912, 15, 14, 7, 337, 17, 107, 2], [645, 4, 131, 1610, 35, 61, 1313, 12, 88, 8, 72, 1506, 523, 1752, 646], [264, 106, 217, 19, 663, 597, 384, 6, 953, 5, 14, 332, 123, 13, 68, 762, 1138], [1391, 7, 1000, 4, ...

# %%
print('before padding : ',len(X[0]))
# padding
X = pad_sequences(X)
print('after padding : ',len(X[0]))
print(X)
# Out:
# before padding :  17
# after padding :  28
# [[   0    0    0 ... 1301 1386  732]
#  [   0    0    0 ...  231  712   17]
#  [   0    0    0 ...  204  366  678]
#  ...
#  [   0    0    0 ...   71   65    3]
#  [   0    0    0 ... 1004 1398   73]
#  [   0    0    0 ...  194    3  710]]

# %%
X.shape
# Out:
# (10729, 28)

# %%
Y  = pd.get_dummies(data['sentiment']).values
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.33,random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (7188, 28) (7188, 2)
# (3541, 28) (3541, 2)

# %%
embed_dim = 256 # output
lstm_out = 512 # LSTM output

model = Sequential()
# Embedding layer is used if we have text data
model.add(Embedding(max_features,embed_dim,input_length=X.shape[1]))
#SpatialDropout1D is used for Embedding layers
model.add(SpatialDropout1D(0.4))
#LSTM layer recurrent_dropout is for recurrent networks
model.add(LSTM(lstm_out,dropout = 0.5,recurrent_dropout=0.5))
# output layer
model.add(Dense(2,activation = 'softmax'))

# compiling
model.compile(loss = 'binary_crossentropy',optimizer = 'adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 28, 256)           512000
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 28, 256)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 512)               1574912
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 2,087,938
# Trainable params: 2,087,938
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
batch_size = 32
model.fit(X_train,Y_train,epochs = 7,batch_size = batch_size,verbose = 1,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/7
# 225/225 [==============================] - 47s 211ms/step - loss: 0.4434 - accuracy: 0.8119 - val_loss: 0.3867 - val_accuracy: 0.8359
# Epoch 2/7
# 225/225 [==============================] - 47s 210ms/step - loss: 0.3394 - accuracy: 0.8575 - val_loss: 0.3585 - val_accuracy: 0.8452
# Epoch 3/7
# 225/225 [==============================] - 47s 207ms/step - loss: 0.2977 - accuracy: 0.8774 - val_loss: 0.3482 - val_accuracy: 0.8540
# Epoch 4/7
# 225/225 [==============================] - 47s 208ms/step - loss: 0.2505 - accuracy: 0.8959 - val_loss: 0.3569 - val_accuracy: 0.8585
# Epoch 5/7
# 225/225 [==============================] - 47s 207ms/step - loss: 0.2298 - accuracy: 0.9079 - val_loss: 0.3607 - val_accuracy: 0.8551
# Epoch 6/7
# 225/225 [==============================] - 46s 204ms/step - loss: 0.2085 - accuracy: 0.9137 - val_loss: 0.4040 - val_accuracy: 0.8512
# Epoch 7/7
# 225/225 [==============================] - 46s 206ms/step - loss: 0.1863 - accuracy: 0.9238 - val_loss: 0.4418 - val_accuracy: 0.8526

# %%
def sentiment_of_tweet(tweet):
    twt = [tweet] #1-D array
    #vectorizing the tweet by the pre-fitted tokenizer instance
    twt = tokenizer.texts_to_sequences(twt)
    #padding the tweet to have exactly the same shape as 'embedding_2' input
    twt = pad_sequences(twt,maxlen=28,dtype='int32',value=0)
    sentiment = model.predict(twt,batch_size = 1,verbose = 2)[0]
    
    print('tweet: {}'.format(tweet))
    
    if(np.argmax(sentiment) == 0):
        print('Negative')
    elif(np.argmax(sentiment) == 1):
        print('Positive')

# %%
sentiment_of_tweet('The food was very delicious')
# Out:
# 1/1 - 0s
# tweet: The food was very delicious
# Positive

# %%
sentiment_of_tweet('The food was worst')
# Out:
# 1/1 - 0s
# tweet: The food was worst
# Negative
